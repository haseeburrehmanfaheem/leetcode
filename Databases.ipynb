# %%
# A relational database stores data in tables (also called relations) with rows and columns. 
# Each table has a schema that defines its structure.
# Table: A collection of rows and columns.

# MySQL
# PostgreSQL
# SQLite
# Microsoft SQL Server
# Oracle

# Atomicity: All or nothing
# Consistency: Data remains valid
# Isolation: No interference between concurrent transactions
# Durability: Data is saved even after system failures




# A non-relational database stores data in formats other than tabular relations 
# — often used for large-scale, unstructured, or semi-structured data.

# 🔄 Types of NoSQL Databases:
# Document Store: Data stored as documents (usually JSON or BSON)

# Example: MongoDB, CouchDB

# %%
# normalization

# to avoid complexities, eliminate duplicates, and organize data in a consistent way.

# 1NF Eliminate repeating groups – make sure every column is atomic, and every row is unique
# Doesnt remove redundancy , therefor we have 2-nf,  has no partial dependency. That is, all non-key attributes are fully dependent on a primary key.

# If your table has a composite primary key (i.e., made of two or more columns), and a column depends on only one part, that’s a partial dependency.


# it does not eliminate transitive partial dependency., therefor we have 3-nf
# have no transitive partial dependency.


https://www.freecodecamp.org/news/database-normalization-1nf-2nf-3nf-table-examples/

# %%
# An index is a data structure (usually a B-Tree or Hash) that the database uses to quickly locate rows without scanning the entire table.

# %%
# Join 2 or more tables based on a related column

# %%
# CAP = Consistency, Availability, Partition Tolerance


# consistency - every read reads the most recent write
# availability - every request gets a non error response 
# partition tolerance - The system continues working even if there are network failures - some nodes cant talk to each other 


# CP (Consistent + Partition Tolerant)	Sacrifices Availability — may reject requests if nodes disagree
# AP (Available + Partition Tolerant)	Sacrifices Consistency — serves old data during partition
# CA (Consistent + Available)	Not possible if network partition occurs (which it eventually will) (only theoretical)
