# %%
# roman to integer
## if the second number is bigger, the first number is subtracted from the total

# Russian doll envelopes
# sort(x = lambda x : x[0], -x[1]) so we can convert it to LCS, and then solve LCS using binarysearch


# Smallest Integer Divisible by K
# instead of doing n = n*10 + 1, we can do n = remainder*10 + 1

# spiral order
# class Solution:
    # def spiralOrder(self, matrix: List[List[int]]) -> List[int]:
    #     m, n = len(matrix), len(matrix[0]) # Initial possible number of steps
    #     direction = 1 # Start off going right
    #     i, j = 0, -1
    #     output = []
    #     while m*n > 0:
    #         for _ in range(n): # move horizontally
    #             j += direction
    #             output.append(matrix[i][j])
    #         m-= 1
    #         for _ in range(m): # move vertically
    #             i += direction
    #             output.append(matrix[i][j])
    #         n-=1
    #         direction *= -1 # flip direction
    #     return output
    
    # crazy solution
    
    
# group shifted strings
# modulo works for negatives as well, which is sweet

# move 0, fast slow pointers crazy solution

# partition list
# build list that is lower, build list that is greater
# combine

# findMaxLength
# use prefix sum and store in dict

# frequency of most frequent elements
# sort and sliding window, and try to make every element equal to the right most element

# 2013. Detect Squares
# go through all the points, and then find the diagonal point, if the diagonal point works, we know the potential other 2 points

# design text editor
# use 2 stacks instead of doubly linked list
