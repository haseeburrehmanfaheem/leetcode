# %%
# search position where number could be inserted
# or return the index where it exists


# 2 ways to solve this
# technically, we would like to replace the first bigger number than target
# easy to implement


l = 0, r = len(nums) - 1
index = len(nums)

while l<=r:
    mid = (l+r)//2
    if nums[mid] >= target:
        index = mid
        r = mid - 1
    else:
        l = mid + 1
return index


# but if we do the other way around, we will have to add 1 to the index, and start index from -1, since the number could also be added at the start

l = 0, r = len(nums) - 1
index = -1

while l<=r:
    mid = (l+r)//2
    if nums[mid] > target:
        r = mid - 1
    elif nums[mid] < target:
        index = mid 
        l = mid + 1
    else:
        return mid 
return index+1
